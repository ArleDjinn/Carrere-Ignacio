# %% [markdown]
# Actividad 2.1. Lectura y Análisis Exploratorio de Datos

# %%
import pandas as pd

cargar = pd.read_csv(r'C:\Users\ignac\OneDrive\Documentos Online\Código\Diplomado Python\Curso 3\datos\ejemplo_data.csv', sep=',', encoding= 'utf-8')

print(cargar.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           5 non-null      int64
#  1   Nombre       5 non-null      object
#  2   2016         5 non-null      object
#  3   2017         5 non-null      object
#  4   Crecimiento  5 non-null      object
#  5   Unidades     5 non-null      object
#  6   fecha        5 non-null      object
#  7   Activo       5 non-null      int64
# dtypes: int64(2), object(6)
# memory usage: 452.0+ bytes
# None

# %%
cargar["ID"] = cargar["ID"].astype(int)
cargar["Activo"] = cargar["Activo"].astype(bool)

print(cargar.info())
print(cargar)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           5 non-null      int64
#  1   Nombre       5 non-null      object
#  2   2016         5 non-null      object
#  3   2017         5 non-null      object
#  4   Crecimiento  5 non-null      object
#  5   Unidades     5 non-null      object
#  6   fecha        5 non-null      object
#  7   Activo       5 non-null      bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 417.0+ bytes
# None
#        ID        Nombre         2016          2017 Crecimiento Unidades  \
# 0   10002     Verde Mar  $125,000.00    $162500.00      30.00%      500
# 1  552278  Manantial sa  $920,000.00  $101,2000.00      10.00%      700
# 2   23477          ACME   $50,000.00      62500.00      25.00%      125
# 3   24900     Andes sur  $350,000.00     490000.00       4.00%       75
# 4  651029     San Pablo   $15,000.00     $12750.00     -15.00%       No
#
#         fecha  Activo
# 0   1-10-2015    True
# 1   6-23-2014   False
# 2   3-12-2016    True
# 3  10-28-2015    True
# 4   2-15-2014   False

# %%
cargar["Unidades"] = cargar["Unidades"].replace(r'[\$,.]', '', regex=True)
cargar["Unidades"] = cargar["Unidades"].replace('No', 0)
cargar["Unidades"] = pd.to_numeric(cargar["Unidades"])
cargar["Unidades"] = cargar["Unidades"].astype(int)

cargar["2016"] = cargar["2016"].replace(r'[\$,.]', '', regex=True)
cargar["2016"] = cargar["2016"].astype(float)

print(cargar.info())
print(cargar)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           5 non-null      int64
#  1   Nombre       5 non-null      object
#  2   2016         5 non-null      float64
#  3   2017         5 non-null      object
#  4   Crecimiento  5 non-null      object
#  5   Unidades     5 non-null      int64
#  6   fecha        5 non-null      object
#  7   Activo       5 non-null      bool
# dtypes: bool(1), float64(1), int64(2), object(4)
# memory usage: 417.0+ bytes
# None
#        ID        Nombre        2016          2017 Crecimiento  Unidades  \
# 0   10002     Verde Mar  12500000.0    $162500.00      30.00%       500
# 1  552278  Manantial sa  92000000.0  $101,2000.00      10.00%       700
# 2   23477          ACME   5000000.0      62500.00      25.00%       125
# 3   24900     Andes sur  35000000.0     490000.00       4.00%        75
# 4  651029     San Pablo   1500000.0     $12750.00     -15.00%         0
#
#         fecha  Activo
# 0   1-10-2015    True
# 1   6-23-2014   False
# 2   3-12-2016    True
# 3  10-28-2015    True
# 4   2-15-2014   False
